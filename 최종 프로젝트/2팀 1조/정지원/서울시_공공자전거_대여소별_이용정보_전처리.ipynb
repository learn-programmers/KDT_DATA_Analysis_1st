# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터 불러오기

# %%
df_2017_01_12 = pd.read_csv('서울특별시 공공자전거 대여소별 이용정보(월간)_2017_1_12.csv', encoding = 'cp949')
df_2018_01_06 = pd.read_csv('/content/서울특별시 공공자전거 대여소별 이용정보(월간)_2018_1_6.csv', encoding = 'cp949')
df_2018_07_11 = pd.read_csv('/content/대여소별 대여정보_201807_11.csv', encoding = 'cp949')

# %%
df_2018_12_2019_05 = pd.read_csv('/content/공공자전거 대여소별 이용정보_201812_201905.csv', encoding = 'cp949')

# %%
df_2019_06_11 = pd.read_csv('/content/공공자전거 대여소별 이용정보_201906_201911.csv', encoding = 'cp949')

# %%
df_2019_12_2020_05 = pd.read_csv('/content/공공자전거 대여소별 이용정보_201912_202005.csv', encoding = 'cp949')

# %%
df_2020_06 = pd.read_csv('/content/공공자전거 대여소별 이용정보_202006.csv', encoding = 'cp949')

# %%
df_2020_07_2021_01 = pd.read_csv('/content/공공자전거 대여소별 이용정보_2020.07~2021.01.csv', encoding = 'cp949')

# %%
df_2021_02_2021_06 = pd.read_csv('/content/공공자전거 대여소별 이용정보_21.02~21.06.csv', encoding = 'cp949')

# %%
df_2021_07_2021_12 = pd.read_csv('/content/대여소별 이용정보(월별 21.7-21.12).csv', encoding = 'cp949')

# %%
df_2022_01 = pd.read_csv('/content/대여소별 이용정보 22.1.csv', encoding = 'cp949')
df_2022_02 = pd.read_csv('/content/대여소별 이용정보 22.2.csv', encoding = 'cp949')
df_2022_03 = pd.read_csv('/content/대여소별 이용정보 22.3.csv', encoding = 'cp949')
df_2022_04 = pd.read_csv('/content/대여소별 이용정보 22.4.csv', encoding = 'cp949')
df_2022_05 = pd.read_csv('/content/대여소별 이용정보 22.5.csv', encoding = 'cp949')
df_2022_06 = pd.read_csv('/content/대여소별 이용정보 22.6.csv', encoding = 'cp949')

# %%
df_2022_07_12 = pd.read_csv('/content/서울특별시 공공자전거 대여소별 이용정보(월별)_22.7-22.12.csv', encoding = 'cp949')
df_2023_01_06 = pd.read_csv('/content/서울특별시 공공자전거 대여소별 이용정보(월별)_23.1-6.csv', encoding = 'cp949')
df_2023_07_12 = pd.read_csv('/content/서울특별시 공공자전거 대여소별 이용정보(월별)_23.7-12.csv', encoding = 'cp949')

# %% [markdown]
# # 데이터 전처리 : 대여소번호 대여소명 대여건수 반납건수 대여연도 대여월로 통일

# %% [markdown]
# ## 2017/01부터 2018/11까지 데이터 형식 : '대여일자'	'대여소번호'	'대여소'	'대여건수'	'반납건수'

# %%
df_2017_01_12.head()
# Out:
#      '대여일자' '대여소번호'              '대여소'  '대여건수'  '반납건수'
# 0  '201701'   '108'         ' 서교동 사거리'     246     198
# 1  '201701'   '503'     ' 더샵스타시티 C동 앞'     246     224
# 2  '201701'   '504'       ' 신자초교입구교차로'     232     261
# 3  '201701'   '505'  ' 자양사거리 광진아크로텔 앞'     302     313
# 4  '201701'   '506'    ' 금호 어울림 아파트 앞'      72      77

# %%
df_2017_01_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8562 entries, 0 to 8561
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   '대여일자'   8562 non-null   object
#  1   '대여소번호'  8543 non-null   object
#  2   '대여소'    8543 non-null   object
#  3   '대여건수'   8562 non-null   int64
#  4   '반납건수'   8562 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 334.6+ KB

# %%
df_2018_01_06.head()
# Out:
#      '대여일자' '대여소번호'            '대여소'  '대여건수'  '반납건수'
# 0  '201801'   '108'       ' 서교동 사거리'     355     422
# 1  '201801'   '503'   ' 더샵스타시티 C동 앞'     287     256
# 2  '201801'   '731'  ' 서울시 도로환경관리센터'       0       4
# 3  '201801'   '504'     ' 신자초교입구교차로'     370     368
# 4  '201801'   '740'          ' 으뜸공원'       0       1

# %%
df_2018_01_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7012 entries, 0 to 7011
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   '대여일자'   7012 non-null   object
#  1   '대여소번호'  7003 non-null   object
#  2   '대여소'    7003 non-null   object
#  3   '대여건수'   7012 non-null   int64
#  4   '반납건수'   7012 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 274.0+ KB

# %%
df_2018_07_11.head()
# Out:
#      대여일자  대여소번호              대여소명  대여건수  반납건수
# 0  201806    101  101. (구)합정동 주민센터   832   807
# 1  201806    102   102. 망원역 1번출구 앞  2819  2568
# 2  201806    103   103. 망원역 2번출구 앞  1977  1769
# 3  201806    104   104. 합정역 1번출구 앞  1682  1610
# 4  201806    105   105. 합정역 5번출구 앞  1105   925

# %%
df_2018_07_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8038 entries, 0 to 8037
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여일자    8038 non-null   int64
#  1   대여소번호   8038 non-null   int64
#  2   대여소명    8038 non-null   object
#  3   대여건수    8038 non-null   int64
#  4   반납건수    8038 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 314.1+ KB

# %% [markdown]
# ### 컬럼과 레코드값 작은따옴표 제거

# %%
df_2017_01_12.columns = df_2017_01_12.columns.str.replace("'","")
df_2018_01_06.columns = df_2018_01_06.columns.str.replace("'","")
df_2018_07_11.columns = df_2018_07_11.columns.str.replace("'","")

# %%
df_2017_01_12 = df_2017_01_12.applymap(lambda x: x.replace("'", "") if isinstance(x, str) else x)
df_2018_01_06 = df_2018_01_06.applymap(lambda x: x.replace("'", "") if isinstance(x, str) else x)
df_2018_07_11 = df_2018_07_11.applymap(lambda x: x.replace("'", "") if isinstance(x, str) else x)

# %% [markdown]
# ### null값 제거

# %%
df_2017_01_12 = df_2017_01_12.dropna()
df_2018_01_06 = df_2018_01_06.dropna()
df_2018_07_11 = df_2018_07_11.dropna()

# %% [markdown]
# ### 대여일자 연도와 월로 나누기

# %%
df_2017_01_12['대여연도'] = df_2017_01_12['대여일자'].str[:4]
df_2017_01_12['대여월'] = df_2017_01_12['대여일자'].str[4:]
df_2017_01_12.drop('대여일자',axis=1,inplace=True)
# Out:
# <ipython-input-21-bc6ed319c0b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_01_12['대여연도'] = df_2017_01_12['대여일자'].str[:4]
# <ipython-input-21-bc6ed319c0b7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_01_12['대여월'] = df_2017_01_12['대여일자'].str[4:]
# <ipython-input-21-bc6ed319c0b7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_2018_01_06['대여연도'] = df_2018_01_06['대여일자'].str[:4]
df_2018_01_06['대여월'] = df_2018_01_06['대여일자'].str[4:]
df_2018_01_06.drop('대여일자',axis=1,inplace=True)
# Out:
# <ipython-input-22-805aa1abe659>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_01_06['대여연도'] = df_2018_01_06['대여일자'].str[:4]
# <ipython-input-22-805aa1abe659>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_01_06['대여월'] = df_2018_01_06['대여일자'].str[4:]
# <ipython-input-22-805aa1abe659>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_2018_07_11['대여일자'] = df_2018_07_11['대여일자'].astype(str)
df_2018_07_11['대여연도'] = df_2018_07_11['대여일자'].str[:4]
df_2018_07_11['대여월'] = df_2018_07_11['대여일자'].str[4:]
df_2018_07_11.drop('대여일자',axis=1,inplace=True)

# %% [markdown]
# ### 데이터 형식 통일 및 병합

# %%
split_data = df_2018_07_11['대여소명'].str.split('.', n=1, expand=True)
df_2018_07_11['대여소번호'] = split_data[0]
df_2018_07_11['대여소명'] = split_data[1].str.strip()

# %%
df_2017_01_12.rename(columns={'대여소': '대여소명'}, inplace=True)
df_2018_01_06.rename(columns={'대여소': '대여소명'}, inplace=True)

# %%
df_2017_01_2018_11 = pd.concat([df_2017_01_12, df_2018_01_06, df_2018_07_11], ignore_index=True)

# %%
df_2017_01_2018_11
# Out:
#       대여소번호             대여소명  대여건수  반납건수  대여연도 대여월
# 0       108          서교동 사거리   246   198  2017  01
# 1       503      더샵스타시티 C동 앞   246   224  2017  01
# 2       504        신자초교입구교차로   232   261  2017  01
# 3       505   자양사거리 광진아크로텔 앞   302   313  2017  01
# 4       506     금호 어울림 아파트 앞    72    77  2017  01
# ...     ...              ...   ...   ...   ...  ..
# 23579  3534     건대입구역 5번출구 뒤  1278  1277  2018  11
# 23580  3535      중곡사거리(국민은행)   459   519  2018  11
# 23581  3536        중앙농협(자양동)   545   535  2018  11
# 23582  3537   아차산 휴먼시아 아파트 옆   267   204  2018  11
# 23583  3538         서울숲 IT캐슬   112    97  2018  11
#
# [23584 rows x 6 columns]

# %% [markdown]
# ## 2018/12 부터 2019/11까지 데이터 형식: 구분	대여소명	대여일자	대여건수

# %%
df_2018_12_2019_05.head()
# Out:
#     구분                            대여소명      대여일자   대여건수
# 0  강남구                2301. 현대고등학교 건너편  201812.0  364.0
# 1  강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  201812.0  500.0
# 2  강남구                  2303. 논현역 7번출구  201812.0  286.0
# 3  강남구         2304. 신영 ROYAL PALACE 앞  201812.0  149.0
# 4  강남구              2305. MCM 본사 직영점 앞  201812.0  145.0

# %%
df_2018_12_2019_05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9189 entries, 0 to 9188
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      9184 non-null   object
#  1   대여소명    9184 non-null   object
#  2   대여일자    9184 non-null   float64
#  3   대여건수    9184 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 287.3+ KB

# %%
df_2019_06_11.head()
# Out:
#   대여소 그룹                           대여소 명  대여 일자 / 월  대여 건수
# 0    강남구                2301. 현대고등학교 건너편     201906   3909
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)     201906   2432
# 2    강남구                  2303. 논현역 7번출구     201906   1567
# 3    강남구         2304. 신영 ROYAL PALACE 앞     201906    559
# 4    강남구              2305. MCM 본사 직영점 앞     201906    730

# %%
df_2019_06_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9272 entries, 0 to 9271
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소 그룹     9272 non-null   object
#  1   대여소 명      9272 non-null   object
#  2   대여 일자 / 월  9272 non-null   int64
#  3   대여 건수      9272 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 289.9+ KB

# %% [markdown]
# ### 결측치 제거

# %%
df_2018_12_2019_05 = df_2018_12_2019_05.dropna()
df_2019_06_11 = df_2019_06_11.dropna()

# %% [markdown]
# ### df_2018_12_2019_05 전처리

# %%
split_data = df_2018_12_2019_05['대여소명'].str.split('.', n=1, expand=True)
df_2018_12_2019_05['대여소번호'] = split_data[0]
df_2018_12_2019_05['대여소명'] = split_data[1].str.strip()

df_2018_12_2019_05['대여연도'] = df_2018_12_2019_05['대여일자'].astype(str).str[:4]
df_2018_12_2019_05['대여월'] = df_2018_12_2019_05['대여일자'].astype(str).str[4:]
# Out:
# <ipython-input-33-6efb7a3c6149>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_12_2019_05['대여소번호'] = split_data[0]
# <ipython-input-33-6efb7a3c6149>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_12_2019_05['대여소명'] = split_data[1].str.strip()
# <ipython-input-33-6efb7a3c6149>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2018_12_2019_05.drop('대여일자', axis=1, inplace=True)
# Out:
# <ipython-input-34-9c8c9353e97c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_12_2019_05.drop('대여일자', axis=1, inplace=True)

# %%
df_2018_12_2019_05['대여건수'] = df_2018_12_2019_05['대여건수'].astype(int)
df_2018_12_2019_05['대여소번호'] = df_2018_12_2019_05['대여소번호'].str[:4]
df_2018_12_2019_05['대여월'] = df_2018_12_2019_05['대여월'].str[:3]
# Out:
# <ipython-input-35-09e55b3b27d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_12_2019_05['대여건수'] = df_2018_12_2019_05['대여건수'].astype(int)
# <ipython-input-35-09e55b3b27d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_12_2019_05['대여소번호'] = df_2018_12_2019_05['대여소번호'].str[:4]
# <ipython-input-35-09e55b3b27d3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2018_12_2019_05['대여월'] = df_2018_12_2019_05['대여월'].str[:2]
# Out:
# <ipython-input-36-5241e8233e4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_12_2019_05['대여월'] = df_2018_12_2019_05['대여월'].str[:2]

# %% [markdown]
# ### df_2019_06_11 전처리

# %%
split_data = df_2019_06_11['대여소 명'].str.split('.', n=1, expand=True)
df_2019_06_11['대여소번호'] = split_data[0]
df_2019_06_11['대여소명'] = split_data[1].str.strip()

df_2019_06_11['대여연도'] = df_2019_06_11['대여 일자 / 월'].astype(str).str[:4]
df_2019_06_11['대여월'] = df_2019_06_11['대여 일자 / 월'].astype(str).str[4:]

# %%
df_2019_06_11.drop('대여 일자 / 월', axis=1, inplace=True)

# %%
df_2019_06_11.drop('대여소 명', axis=1, inplace=True)

# %% [markdown]
# ### 데이터 통일 및 병합

# %%
df_2019_06_11.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2018_12_2019_05.rename(columns={'구분':'자치구'}, inplace=True)
df_2019_06_11.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

# %%
df_2018_12_2019_11 = pd.concat([df_2018_12_2019_05, df_2019_06_11], ignore_index=True)

# %%
df_2018_12_2019_11
# Out:
#        자치구                      대여소명  대여건수 대여소번호  대여연도 대여월
# 0      강남구                현대고등학교 건너편   364  2301  2018  12
# 1      강남구  교보타워 버스정류장(신논현역 3번출구 후면)   500  2302  2018  12
# 2      강남구                  논현역 7번출구   286  2303  2018  12
# 3      강남구         신영 ROYAL PALACE 앞   149  2304  2018  12
# 4      강남구              MCM 본사 직영점 앞   145  2305  2018  12
# ...    ...                       ...   ...   ...   ...  ..
# 18451  중랑구                 상봉역 2번 출구  1205  1455  2019  11
# 18452  중랑구            상아빌딩(우림시장 교차로)   764  1456  2019  11
# 18453  중랑구                     동원사거리   577  1457  2019  11
# 18454  중랑구                    상봉터미널2  1243  1458  2019  11
# 18455  중랑구                용마한신아파트사거리   339  1459  2019  11
#
# [18456 rows x 6 columns]

# %% [markdown]
# ## 2019/12 부터 2020/06까지 데이터 형식 : 대여소 그룹	대여소 명	대여 일자 / 월	대여 건수 반납건수

# %%
df_2019_12_2020_05.head()
# Out:
#   대여소 그룹                           대여소 명  일자 / 월  대여 건수  반납 건수
# 0    강남구                2301. 현대고등학교 건너편  201912    501    662
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  201912    737    736
# 2    강남구                  2303. 논현역 7번출구  201912    460    438
# 3    강남구         2304. 신영 ROYAL PALACE 앞  201912    150     62
# 4    강남구              2305. MCM 본사 직영점 앞  201912    257    342

# %%
df_2019_12_2020_05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10003 entries, 0 to 10002
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  10003 non-null  object
#  1   대여소 명   10003 non-null  object
#  2   일자 / 월  10003 non-null  int64
#  3   대여 건수   10003 non-null  int64
#  4   반납 건수   10003 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 390.9+ KB

# %%
df_2020_06.head()
# Out:
#   대여소 그룹                           대여소 명  일자 / 월  대여 건수  반납 건수
# 0    강남구                2301. 현대고등학교 건너편  202006   4512   4714
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  202006   1650   1628
# 2    강남구                  2303. 논현역 7번출구  202006   1134   1072
# 3    강남구         2304. 신영 ROYAL PALACE 앞  202006    399    130
# 4    강남구              2305. MCM 본사 직영점 앞  202006    490    475

# %%
df_2020_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2062 entries, 0 to 2061
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2062 non-null   object
#  1   대여소 명   2062 non-null   object
#  2   일자 / 월  2062 non-null   int64
#  3   대여 건수   2062 non-null   int64
#  4   반납 건수   2062 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 80.7+ KB

# %% [markdown]
# ### 데이터 전처리 : 대여소 명 -> 대여소번호과 대여소명으로 바꾸기, 일자 / 월 -> 대여연도와 대여월로 바꾸기

# %%
split_data = df_2019_12_2020_05['대여소 명'].str.split('.', n=1, expand=True)
df_2019_12_2020_05['대여소번호'] = split_data[0]
df_2019_12_2020_05['대여소명'] = split_data[1].str.strip()

split_data = df_2020_06['대여소 명'].str.split('.', n=1, expand=True)
df_2020_06['대여소번호'] = split_data[0]
df_2020_06['대여소명'] = split_data[1].str.strip()

df_2019_12_2020_05['대여연도'] = df_2019_12_2020_05['일자 / 월'].astype(str).str[:4]
df_2019_12_2020_05['대여월'] = df_2019_12_2020_05['일자 / 월'].astype(str).str[4:]

df_2020_06['대여연도'] = df_2020_06['일자 / 월'].astype(str).str[:4]
df_2020_06['대여월'] = df_2020_06['일자 / 월'].astype(str).str[4:]

# %%
df_2019_12_2020_05.drop('대여소 명', axis=1, inplace=True)
df_2019_12_2020_05.drop('일자 / 월', axis=1, inplace=True)
df_2020_06.drop('대여소 명', axis=1, inplace=True)
df_2020_06.drop('일자 / 월', axis=1, inplace=True)

# %% [markdown]
# ### 데이터 통일 및 병합 : 대여 건수, 반납 건수 -> 대여건수,반납건수로 바꾸기 / 대여소 그룹 -> 자치구로 바꾸기

# %%
df_2019_12_2020_05.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2019_12_2020_05.rename(columns={'반납 건수':'반납건수'}, inplace=True)
df_2019_12_2020_05.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

df_2020_06.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2020_06.rename(columns={'반납 건수':'반납건수'}, inplace=True)
df_2020_06.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

# %%
df_2019_12_2020_06 = pd.concat([df_2019_12_2020_05, df_2020_06], ignore_index=True)

# %%
df_2019_12_2020_06
# Out:
#        자치구  대여건수  반납건수 대여소번호                      대여소명  대여연도 대여월
# 0      강남구   501   662  2301                현대고등학교 건너편  2019  12
# 1      강남구   737   736  2302  교보타워 버스정류장(신논현역 3번출구 후면)  2019  12
# 2      강남구   460   438  2303                  논현역 7번출구  2019  12
# 3      강남구   150    62  2304         신영 ROYAL PALACE 앞  2019  12
# 4      강남구   257   342  2305              MCM 본사 직영점 앞  2019  12
# ...    ...   ...   ...   ...                       ...   ...  ..
# 12060  중랑구    85    83  1473       중랑역 1번 출구(중화문화복지센터)  2020  06
# 12061  중랑구    85    82  1477                 면목삼익아파트 앞  2020  06
# 12062  중랑구   322   329  1478                홈플러스 상봉점 앞  2020  06
# 12063  중랑구   150   166  1479                 면목 홈플러스 2  2020  06
# 12064  중랑구   235   243  1480                   용마지구대 옆  2020  06
#
# [12065 rows x 7 columns]

# %% [markdown]
# ## 2020/07 부터 2021/12까지 데이터 형식 : 대여소 그룹	대여소 명	대여 일자 / 월	대여 건수

# %%
df_2020_07_2021_01.head()
# Out:
#   대여소 그룹                           대여소 명  대여 일자 / 월  대여 건수
# 0    강남구                2301. 현대고등학교 건너편     202007   3997
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)     202007   1250
# 2    강남구                  2303. 논현역 7번출구     202007    863
# 3    강남구         2304. 신영 ROYAL PALACE 앞     202007    334
# 4    강남구              2305. MCM 본사 직영점 앞     202007    436

# %%
df_2020_07_2021_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14754 entries, 0 to 14753
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소 그룹     14754 non-null  object
#  1   대여소 명      14754 non-null  object
#  2   대여 일자 / 월  14754 non-null  int64
#  3   대여 건수      14754 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 461.2+ KB

# %%
df_2021_02_2021_06.head()
# Out:
#   대여소 그룹                           대여소 명  대여 일자 / 월   대여 건수
# 0    강남구                2301. 현대고등학교 건너편   202102.0  1713.0
# 1    강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)   202102.0   538.0
# 2    강남구                  2303. 논현역 7번출구   202102.0   440.0
# 3    강남구         2304. 신영 ROYAL PALACE 앞   202102.0   156.0
# 4    강남구              2305. MCM 본사 직영점 앞   202102.0   197.0

# %%
df_2021_02_2021_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14749 entries, 0 to 14748
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소 그룹     11776 non-null  object
#  1   대여소 명      11776 non-null  object
#  2   대여 일자 / 월  11776 non-null  float64
#  3   대여 건수      11776 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 461.0+ KB

# %%
df_2021_07_2021_12.head()
# Out:
#    대여소 그룹                           대여소 명  대여 일자 / 월  대여 건수
# 0  그룹명 없음                         대여소명 없음     202107      0
# 1     강남구                2301. 현대고등학교 건너편     202107   2545
# 2     강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)     202107   1176
# 3     강남구                  2303. 논현역 7번출구     202107   1467
# 4     강남구         2304. 신영 ROYAL PALACE 앞     202107    349

# %%
df_2021_07_2021_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15148 entries, 0 to 15147
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소 그룹     15148 non-null  object
#  1   대여소 명      15148 non-null  object
#  2   대여 일자 / 월  15148 non-null  int64
#  3   대여 건수      15148 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 473.5+ KB

# %% [markdown]
# ### 데이터 전처리 : 대여소 명 -> 대여소번호과 대여소명으로 바꾸기, 일자 / 월 -> 대여연도와 대여월로 바꾸기

# %%
split_data = df_2020_07_2021_01['대여소 명'].str.split('.', n=1, expand=True)
df_2020_07_2021_01['대여소번호'] = split_data[0]
df_2020_07_2021_01['대여소명'] = split_data[1].str.strip()

split_data = df_2021_02_2021_06['대여소 명'].str.split('.', n=1, expand=True)
df_2021_02_2021_06['대여소번호'] = split_data[0]
df_2021_02_2021_06['대여소명'] = split_data[1].str.strip()

split_data = df_2021_07_2021_12['대여소 명'].str.split('.', n=1, expand=True)
df_2021_07_2021_12['대여소번호'] = split_data[0]
df_2021_07_2021_12['대여소명'] = split_data[1].str.strip()


df_2020_07_2021_01['대여연도'] = df_2020_07_2021_01['대여 일자 / 월'].astype(str).str[:4]
df_2020_07_2021_01['대여월'] = df_2020_07_2021_01['대여 일자 / 월'].astype(str).str[4:]

df_2021_02_2021_06['대여연도'] = df_2021_02_2021_06['대여 일자 / 월'].astype(str).str[:4]
df_2021_02_2021_06['대여월'] = df_2021_02_2021_06['대여 일자 / 월'].astype(str).str[4:]

df_2021_07_2021_12['대여연도'] = df_2021_07_2021_12['대여 일자 / 월'].astype(str).str[:4]
df_2021_07_2021_12['대여월'] = df_2021_07_2021_12['대여 일자 / 월'].astype(str).str[4:]

# %%
df_2020_07_2021_01.drop('대여소 명', axis=1, inplace=True)
df_2020_07_2021_01.drop('대여 일자 / 월', axis=1, inplace=True)

df_2021_02_2021_06.drop('대여소 명', axis=1, inplace=True)
df_2021_02_2021_06.drop('대여 일자 / 월', axis=1, inplace=True)

df_2021_07_2021_12.drop('대여소 명', axis=1, inplace=True)
df_2021_07_2021_12.drop('대여 일자 / 월', axis=1, inplace=True)

# %% [markdown]
# ### 데이터 통일 및 병합 : 대여 건수-> 대여건수로 바꾸기 / 대여소 그룹 -> 자치구로 바꾸기

# %%
df_2020_07_2021_01.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2020_07_2021_01.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

df_2021_02_2021_06.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2021_02_2021_06.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

df_2021_07_2021_12.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2021_07_2021_12.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

# %%
df_2020_07_2021_12 = pd.concat([df_2020_07_2021_01, df_2021_02_2021_06, df_2021_07_2021_12], ignore_index=True)

# %%
df_2020_07_2021_12
# Out:
#        자치구    대여건수 대여소번호                      대여소명  대여연도 대여월
# 0      강남구  3997.0  2301                현대고등학교 건너편  2020  07
# 1      강남구  1250.0  2302  교보타워 버스정류장(신논현역 3번출구 후면)  2020  07
# 2      강남구   863.0  2303                  논현역 7번출구  2020  07
# 3      강남구   334.0  2304         신영 ROYAL PALACE 앞  2020  07
# 4      강남구   436.0  2305              MCM 본사 직영점 앞  2020  07
# ...    ...     ...   ...                       ...   ...  ..
# 44646  중랑구   159.0  4827               신내SK V1센터 앞  2021  12
# 44647  중랑구   371.0  4828            신내동 한살림 중랑지구 앞  2021  12
# 44648  중랑구   159.0  4829               신내동 마석감자탕 앞  2021  12
# 44649  중랑구    60.0  4834                  용마복지센터 앞  2021  12
# 44650  중랑구   218.0  4835                  망우동 본죽 앞  2021  12
#
# [44651 rows x 6 columns]

# %% [markdown]
# ## 2022/01 부터 2022/06까지 데이터 형식 : 대여소 그룹	팀명	대여소 명	대여 건수

# %%
df_2022_01.head()
# Out:
#   대여소 그룹    팀명            대여소 명  대여 건수
# 0    강동구  천호1팀  1014. 강동구평생학습관앞      3
# 1    성동구   테스트        9980. 에이텍      3
# 2    동작구  영남2팀   2063. 대방역 4번출구      4
# 3    서초구  이수1팀     2286. 탑성마을입구      7
# 4    서초구  이수1팀     2288. 안골마을입구      7

# %%
df_2022_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2588 entries, 0 to 2587
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2588 non-null   object
#  1   팀명      2588 non-null   object
#  2   대여소 명   2588 non-null   object
#  3   대여 건수   2588 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 81.0+ KB

# %%
df_2022_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2594 entries, 0 to 2593
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2594 non-null   object
#  1   팀명      2594 non-null   object
#  2   대여소 명   2594 non-null   object
#  3   대여 건수   2594 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 81.2+ KB

# %%
df_2022_03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2607 entries, 0 to 2606
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2607 non-null   object
#  1   팀명      2607 non-null   object
#  2   대여소 명   2607 non-null   object
#  3   대여 건수   2607 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 81.6+ KB

# %%
df_2022_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2602 entries, 0 to 2601
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2602 non-null   object
#  1   팀명      2602 non-null   object
#  2   대여소 명   2602 non-null   object
#  3   대여 건수   2602 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 81.4+ KB

# %%
df_2022_05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2616 entries, 0 to 2615
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2616 non-null   object
#  1   팀명      2616 non-null   object
#  2   대여소 명   2616 non-null   object
#  3   대여 건수   2616 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 81.9+ KB

# %%
df_2022_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 그룹  2627 non-null   object
#  1   팀명      2627 non-null   object
#  2   대여소 명   2627 non-null   object
#  3   대여 건수   2627 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 82.2+ KB

# %% [markdown]
# ### 각 데이터프레임 별 대여연도, 대여월 할당

# %%
df_2022_01 = df_2022_01.assign(대여연도='2022', 대여월='01')
df_2022_02 = df_2022_02.assign(대여연도='2022', 대여월='02')
df_2022_03 = df_2022_03.assign(대여연도='2022', 대여월='03')
df_2022_04 = df_2022_04.assign(대여연도='2022', 대여월='04')
df_2022_05 = df_2022_05.assign(대여연도='2022', 대여월='05')
df_2022_06 = df_2022_06.assign(대여연도='2022', 대여월='06')

# %% [markdown]
# ### 데이터 병합 및 전처리 : 대여소 그룹 -> 자치구 / 대여 건수 -> 대여건수 / 팀명 삭제 / 대여소 명 -> 대여소번호,대여소명으로 바꾸기

# %%
df_2022_01_06 = pd.concat([df_2022_01, df_2022_02, df_2022_03, df_2022_04, df_2022_05, df_2022_06], ignore_index=True)

# %%
df_2022_01_06
# Out:
#       대여소 그룹    팀명               대여소 명  대여 건수  대여연도 대여월
# 0        강동구  천호1팀     1014. 강동구평생학습관앞      3  2022  01
# 1        성동구   테스트           9980. 에이텍      3  2022  01
# 2        동작구  영남2팀      2063. 대방역 4번출구      4  2022  01
# 3        서초구  이수1팀        2286. 탑성마을입구      7  2022  01
# 4        서초구  이수1팀        2288. 안골마을입구      7  2022  01
# ...      ...   ...                 ...    ...   ...  ..
# 15629   영등포구  영남3팀   207. 여의나루역 1번출구 앞  13595  2022  06
# 15630    관악구  영남2팀       2102. 봉림교 교통섬  13722  2022  06
# 15631    광진구  중랑1팀  502. 뚝섬유원지역 1번출구 앞  14125  2022  06
# 15632    마포구  상암1팀    4217. 한강공원 망원나들목  15417  2022  06
# 15633    강서구  개화1팀    2715.마곡나루역 2번 출구  16498  2022  06
#
# [15634 rows x 6 columns]

# %%
split_data = df_2022_01_06['대여소 명'].str.split('.', n=1, expand=True)
df_2022_01_06['대여소번호'] = split_data[0]
df_2022_01_06['대여소명'] = split_data[1].str.strip()

# %%
df_2022_01_06.drop('대여소 명', axis=1, inplace=True)
df_2022_01_06.drop('팀명', axis=1, inplace=True)

# %%
df_2022_01_06.rename(columns={'대여 건수':'대여건수'}, inplace=True)
df_2022_01_06.rename(columns={'대여소 그룹':'자치구'}, inplace=True)

# %% [markdown]
# ## 2022/07 부터 2023/12까지 데이터 형식 : 자치구	대여소명	기준년월	대여건수	반납건수

# %%
df_2022_07_12.head()
# Out:
#    자치구                            대여소명    기준년월   대여건수   반납건수
# 0  강남구                2301. 현대고등학교 건너편  202207  2,170  2,183
# 1  강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  202207  1,140  1,143
# 2  강남구                 2303. 논현역 10번출구  202207  1,329  1,196
# 3  강남구                    2304. 대현그린타워  202207    288    104
# 4  강남구              2305. MCM 본사 직영점 앞  202207    334    342

# %%
df_2022_07_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16019 entries, 0 to 16018
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     16019 non-null  object
#  1   대여소명    16019 non-null  object
#  2   기준년월    16019 non-null  int64
#  3   대여건수    16019 non-null  object
#  4   반납건수    16019 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 625.9+ KB

# %%
df_2023_01_06.head()
# Out:
#    자치구                            대여소명    기준년월   대여건수   반납건수
# 0  강남구                2301. 현대고등학교 건너편  202301   383    439
# 1  강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  202301   433    446
# 2  강남구                 2303. 논현역 10번출구  202301   648    508
# 3  강남구                    2304. 대현그린타워  202301    76     55
# 4  강남구              2305. MCM 본사 직영점 앞  202301   172    179

# %%
df_2023_01_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16306 entries, 0 to 16305
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     16306 non-null  object
#  1   대여소명    16306 non-null  object
#  2   기준년월    16306 non-null  int64
#  3   대여건수    16306 non-null  object
#  4   반납건수    16306 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 637.1+ KB

# %%
df_2023_07_12.head()
# Out:
#    자치구               대여소명    기준년월  대여건수  반납건수
# 0  마포구       108. 서교동 사거리  202307  2019  2019
# 1  양천구   729. 서부식자재마트 건너편  202307  2105  2268
# 2  양천구  731. 서울시 도로환경관리센터  202307  3975  4042
# 3  양천구         732. 신월중학교  202307  1284  1260
# 4  양천구   733. 신정이펜하우스314동  202307   934   451

# %%
df_2023_07_12.head()
# Out:
#    자치구               대여소명    기준년월  대여건수  반납건수
# 0  마포구       108. 서교동 사거리  202307  2019  2019
# 1  양천구   729. 서부식자재마트 건너편  202307  2105  2268
# 2  양천구  731. 서울시 도로환경관리센터  202307  3975  4042
# 3  양천구         732. 신월중학교  202307  1284  1260
# 4  양천구   733. 신정이펜하우스314동  202307   934   451

# %% [markdown]
# ### 데이터 병합부터 2022/07 ~ 2023/12

# %%
df_2022_07_2023_12 = pd.concat([df_2022_07_12, df_2023_01_06, df_2023_07_12], ignore_index=True)

# %%
df_2022_07_2023_12
# Out:
#        자치구                            대여소명    기준년월   대여건수   반납건수
# 0      강남구                2301. 현대고등학교 건너편  202207  2,170  2,183
# 1      강남구  2302. 교보타워 버스정류장(신논현역 3번출구 후면)  202207  1,140  1,143
# 2      강남구                 2303. 논현역 10번출구  202207  1,329  1,196
# 3      강남구                    2304. 대현그린타워  202207    288    104
# 4      강남구              2305. MCM 본사 직영점 앞  202207    334    342
# ...    ...                             ...     ...    ...    ...
# 48701  양천구    722. 경서농협 버스정류장(우리은행신정동지점방향)  202312    951    996
# 48702  양천구                     723. SBS방송국  202312   1707   1679
# 48703  양천구            724. 계남공원 입구 주출입구 좌측  202312    138     94
# 48704  양천구                 725. 양강중학교앞 교차로  202312    299    138
# 48705  양천구              726. 목동3단지 시내버스정류장  202312   2345   2347
#
# [48706 rows x 5 columns]

# %% [markdown]
# ### 데이터 전처리: 대여소명 -> 대여소번호와 대여소명 / 기준년월 -> 대여연도와 대여월

# %%
split_data = df_2022_07_2023_12['대여소명'].str.split('.', n=1, expand=True)
df_2022_07_2023_12['대여소번호'] = split_data[0]
df_2022_07_2023_12['대여소명'] = split_data[1].str.strip()

df_2022_07_2023_12['대여연도'] = df_2022_07_2023_12['기준년월'].astype(str).str[:4]
df_2022_07_2023_12['대여월'] = df_2022_07_2023_12['기준년월'].astype(str).str[4:]

# %%
df_2022_07_2023_12.drop('기준년월', axis=1, inplace=True)

# %% [markdown]
# # EDA

# %% [markdown]
# ## 2017/01 ~ 2018/11

# %%
df_2017_01_2018_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23584 entries, 0 to 23583
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   23584 non-null  object
#  1   대여소명    23584 non-null  object
#  2   대여건수    23584 non-null  int64
#  3   반납건수    23584 non-null  int64
#  4   대여연도    23584 non-null  object
#  5   대여월     23584 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ MB

# %%
df_2017_01_2018_11.describe()
# Out:
#                대여건수         반납건수
# count  23584.000000  23584.00000
# mean     651.240799    648.60893
# std      650.267522    680.79500
# min        0.000000      0.00000
# 25%      219.000000    200.00000
# 50%      473.000000    456.00000
# 75%      880.250000    880.00000
# max    12207.000000  12332.00000

# %%
df_2017_01_2018_11.sort_values(by='대여건수', ascending=False).head(10)
# Out:
#       대여소번호                     대여소명   대여건수   반납건수  대여연도 대여월
# 19465   207             여의나루역 1번출구 앞  12207  12185  2018  09
# 19656   502            뚝섬유원지역 1번출구 앞  10958  12332  2018  09
# 5367    207             여의나루역 1번출구 앞   9971   9724  2017  09
# 15277   207             여의나루역 1번출구 앞   8707   8153  2018  06
# 15645   207             여의나루역 1번출구 앞   8707   8153  2018  06
# 14007   207             여의나루역 1번출구 앞   8632   8639  2018  05
# 6264    207             여의나루역 1번출구 앞   7823   7678  2017  10
# 5621    502            뚝섬유원지역 1번출구 앞   7603   8519  2017  09
# 20500  2219  고속터미널역 8-1번, 8-2번 출구 사이   7523   7865  2018  09
# 20785   207             여의나루역 1번출구 앞   7508   7026  2018  10

# %%
df_2017_01_2018_11.sort_values(by='대여건수', ascending=False).tail(10)
# Out:
#       대여소번호                대여소명  대여건수  반납건수  대여연도 대여월
# 10690  1268        몽촌토성역 1번출구 옆     0     8  2018  03
# 2899   1808       에이스하이엔드타워8차 앞     0     2  2017  06
# 2859   1332        석계역 5번출구 건너편     0     2  2017  06
# 2856   1327           상월곡역 3번출구     0     1  2017  06
# 2836   1234         레이크팰리스 동문우측     0     8  2017  06
# 10744  2062             사당새마을금고     0     1  2018  03
# 10758  2363         강남 을지병원 교차로     0     5  2018  03
# 2442    350  KEB 하나은행(내자동 지점) 앞     0     1  2017  06
# 2332   1830           빅마켓 금천점 앞     0     1  2017  05
# 4655   1218            방이역 4번출구     0    25  2017  08

# %%
df_2017_01_2018_11.sort_values(by='반납건수', ascending=False).head(10)
# Out:
#       대여소번호            대여소명   대여건수   반납건수  대여연도 대여월
# 19656   502   뚝섬유원지역 1번출구 앞  10958  12332  2018  09
# 19465   207    여의나루역 1번출구 앞  12207  12185  2018  09
# 5367    207    여의나루역 1번출구 앞   9971   9724  2017  09
# 14007   207    여의나루역 1번출구 앞   8632   8639  2018  05
# 5621    502   뚝섬유원지역 1번출구 앞   7603   8519  2017  09
# 15538   502   뚝섬유원지역 1번출구 앞   7438   8495  2018  06
# 15829   502   뚝섬유원지역 1번출구 앞   7438   8495  2018  06
# 15645   207    여의나루역 1번출구 앞   8707   8153  2018  06
# 15277   207    여의나루역 1번출구 앞   8707   8153  2018  06
# 14268   502   뚝섬유원지역 1번출구 앞   7131   8142  2018  05

# %%
df_2017_01_2018_11.sort_values(by='반납건수', ascending=False).tail(10)
# Out:
#       대여소번호              대여소명  대여건수  반납건수  대여연도 대여월
# 8542    722     LG전자베스트샵 신정점      1     0  2017  12
# 7496      7              이동정비     1     0  2017  11
# 3059   1228            마천사거리      1     0  2017  06
# 6597   2371         한국우편사업진흥원     1     0  2017  11
# 10839  1671             인덕대학교     1     0  2018  03
# 6568   1526          수유동 채선당앞     2     0  2017  11
# 23538  2616           거여동 사거리     2     0  2018  11
# 10618   724   계남공원 입구 주출입구 좌측     4     0  2018  02
# 21519  1365            선잠단지 앞    10     0  2018  10
# 3060   1230          송파중학교 정문     2     0  2017  06

# %%
df_2017_01_2018_11.groupby('대여월')[['대여건수','반납건수']].mean()
# Out:
#             대여건수         반납건수
# 대여월
# 01    163.723462   163.112914
# 02    164.370047   163.795165
# 03    396.653257   395.099617
# 04    535.897831   533.583904
# 05    744.581459   741.552386
# 06    905.799382   902.499536
# 07    716.039282   712.713870
# 08    702.665577   699.307800
# 09   1029.276500  1025.120884
# 10    931.474774   927.909444
# 11    570.979268   568.868293
# 12    189.048031   188.176753

# %% [markdown]
# ## 2018/12 ~ 2019/11

# %%
df_2018_12_2019_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18456 entries, 0 to 18455
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     18456 non-null  object
#  1   대여소명    18435 non-null  object
#  2   대여건수    18456 non-null  int64
#  3   대여소번호   18456 non-null  object
#  4   대여연도    18456 non-null  object
#  5   대여월     18456 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 865.2+ KB

# %%
df_2018_12_2019_11.describe()
# Out:
#                대여건수
# count  18456.000000
# mean    1000.180592
# std     1022.889675
# min        0.000000
# 25%      331.000000
# 50%      697.000000
# 75%     1340.000000
# max    16080.000000

# %%
df_2018_12_2019_11.groupby('자치구').sum().sort_values(by='대여건수', ascending=False)
# Out:
# <ipython-input-95-66a36a069f9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_2018_12_2019_11.groupby('자치구').sum().sort_values(by='대여건수', ascending=False)
#            대여건수
# 자치구
# 송파구     1550841
# 영등포구    1521902
# 마포구     1323691
# 광진구     1169242
# 강서구     1128785
# 노원구      915608
# 성동구      881792
# 서초구      836244
# 강남구      790737
# 종로구      776034
# 관악구      667287
# 구로구      664399
# 강동구      652896
# 동대문구     648020
# 성북구      604375
# 서대문구     560931
# 은평구      544344
# 양천구      537121
# 중랑구      473049
# 동작구      466406
# 중구       444378
# 용산구      381281
# 강북구      327191
# 도봉구      306459
# 금천구      285370
# 정비센터        950
# 그룹명 없음        0

# %% [markdown]
# ## 2019/12 ~ 2020/06

# %%
df_2019_12_2020_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12065 entries, 0 to 12064
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     12065 non-null  object
#  1   대여건수    12065 non-null  int64
#  2   반납건수    12065 non-null  int64
#  3   대여소번호   12065 non-null  object
#  4   대여소명    12033 non-null  object
#  5   대여연도    12065 non-null  object
#  6   대여월     12065 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 659.9+ KB

# %%
df_2019_12_2020_06.describe()
# Out:
#                대여건수          반납건수
# count  12065.000000  12065.000000
# mean     943.717862    941.848902
# std     1102.779522   1164.247716
# min        0.000000      0.000000
# 25%      307.000000    279.000000
# 50%      621.000000    607.000000
# 75%     1211.000000   1211.000000
# max    23174.000000  24256.000000

# %% [markdown]
# ## 2020/07 ~ 2021/12

# %%
df_2020_07_2021_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44651 entries, 0 to 44650
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     41678 non-null  object
#  1   대여건수    41678 non-null  float64
#  2   대여소번호   41678 non-null  object
#  3   대여소명    41555 non-null  object
#  4   대여연도    44651 non-null  object
#  5   대여월     44651 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.0+ MB

# %%
df_2020_07_2021_12.describe()
# Out:
#                대여건수
# count  41678.000000
# mean    1086.217357
# std     1070.758747
# min        0.000000
# 25%      398.000000
# 50%      792.000000
# 75%     1425.000000
# max    20258.000000

# %% [markdown]
# ## 2022/01 ~ 2022/06

# %%
df_2022_01_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15634 entries, 0 to 15633
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     15634 non-null  object
#  1   대여건수    15634 non-null  int64
#  2   대여연도    15634 non-null  object
#  3   대여월     15634 non-null  object
#  4   대여소번호   15634 non-null  object
#  5   대여소명    15634 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 733.0+ KB

# %%
df_2022_01_06.describe()
# Out:
#                대여건수
# count  15634.000000
# mean    1177.301075
# std     1283.555145
# min        0.000000
# 25%      388.000000
# 50%      785.000000
# 75%     1518.000000
# max    22589.000000

# %% [markdown]
# ## 2022/07 ~ 2023/12

# %%
df_2022_07_2023_12.head()
# Out:
#    자치구                      대여소명   대여건수   반납건수 대여소번호  대여연도 대여월
# 0  강남구                현대고등학교 건너편  2,170  2,183  2301  2022  07
# 1  강남구  교보타워 버스정류장(신논현역 3번출구 후면)  1,140  1,143  2302  2022  07
# 2  강남구                 논현역 10번출구  1,329  1,196  2303  2022  07
# 3  강남구                    대현그린타워    288    104  2304  2022  07
# 4  강남구              MCM 본사 직영점 앞    334    342  2305  2022  07

# %%
df_2022_07_2023_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48706 entries, 0 to 48705
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     48706 non-null  object
#  1   대여소명    48700 non-null  object
#  2   대여건수    48706 non-null  object
#  3   반납건수    48706 non-null  object
#  4   대여소번호   48706 non-null  object
#  5   대여연도    48706 non-null  object
#  6   대여월     48706 non-null  object
# dtypes: object(7)
# memory usage: 2.6+ MB

# %% [markdown]
# ## 2017/01 ~ 2023/12 병합

# %%
df_2017_01_2023_12 = pd.concat([df_2017_01_2018_11, df_2018_12_2019_11, df_2019_12_2020_06, df_2020_07_2021_12, df_2022_01_06, df_2022_07_2023_12 ], ignore_index=True)

# %%
df_2017_01_2023_12.head()
# Out:
#   대여소번호             대여소명 대여건수 반납건수  대여연도 대여월  자치구
# 0   108          서교동 사거리  246  198  2017  01  NaN
# 1   503      더샵스타시티 C동 앞  246  224  2017  01  NaN
# 2   504        신자초교입구교차로  232  261  2017  01  NaN
# 3   505   자양사거리 광진아크로텔 앞  302  313  2017  01  NaN
# 4   506     금호 어울림 아파트 앞   72   77  2017  01  NaN

# %%
df_2017_01_2023_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160123 entries, 0 to 163095
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대여소번호   160123 non-null  object
#  1   대여소명    159941 non-null  object
#  2   대여건수    160123 non-null  object
#  3   반납건수    84355 non-null   object
#  4   대여연도    160123 non-null  object
#  5   대여월     160123 non-null  object
#  6   자치구     136539 non-null  object
# dtypes: object(7)
# memory usage: 9.8+ MB

# %%
df_2017_01_2023_12.to_csv('서울시 공공자전거 대여소별 이용정보(월별).csv', index=False, encoding = 'cp949')

# %%
df_2017_01_2023_12[df_2017_01_2023_12['대여연도']=='nan']
# Out:
#       대여소번호 대여소명 대여건수 반납건수 대여연도 대여월  자치구
# 80635   NaN  NaN  NaN  NaN  nan      NaN
# 80636   NaN  NaN  NaN  NaN  nan      NaN
# 80637   NaN  NaN  NaN  NaN  nan      NaN
# 80638   NaN  NaN  NaN  NaN  nan      NaN
# 80639   NaN  NaN  NaN  NaN  nan      NaN
# ...     ...  ...  ...  ...  ...  ..  ...
# 83603   NaN  NaN  NaN  NaN  nan      NaN
# 83604   NaN  NaN  NaN  NaN  nan      NaN
# 83605   NaN  NaN  NaN  NaN  nan      NaN
# 83606   NaN  NaN  NaN  NaN  nan      NaN
# 83607   NaN  NaN  NaN  NaN  nan      NaN
#
# [2973 rows x 7 columns]

# %%
df_2017_01_2023_12 = df_2017_01_2023_12[df_2017_01_2023_12['대여연도'] != 'nan']

# %%
df_2017_01_2023_12['대여건수'] = df_2017_01_2023_12['대여건수'].fillna(0).str.replace(',','').astype(int)
df_2017_01_2023_12['반납건수'] = df_2017_01_2023_12['반납건수'].fillna(0).str.replace(',','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-c082a700f295> in <cell line: 1>()
# ----> 1 df_2017_01_2023_12['대여건수'] = df_2017_01_2023_12['대여건수'].fillna(0).str.replace(',','').astype(int)
#       2 df_2017_01_2023_12['반납건수'] = df_2017_01_2023_12['반납건수'].fillna(0).str.replace(',','').astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
# ...

# %%
df_2017_01_2023_12[df_2017_01_2023_12['대여건수'].isna()]
# Out:
# Empty DataFrame
# Columns: [대여소번호, 대여소명, 대여건수, 반납건수, 대여연도, 대여월, 자치구]
# Index: []
