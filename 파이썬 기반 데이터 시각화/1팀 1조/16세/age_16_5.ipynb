# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student.csv')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df = df[df['age'] == 16]
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 562     MS   F   16       R     LE3       T     2     2     other  services
# 564     MS   M   16       R     GT3       T     3     2  services     other
# 565     MS   M   16       R     LE3       T     1     1   at_home     other
# 570     MS   M   16       R     GT3       T     2     2  services  services
# 572     MS   F   16       U     GT3       A     3     2  services   at_home
#
# ...

# %%
### Dalc, Walc에 따른 veryLow, Low, other 열 추가

def classify_Alc(row):
    
    if row['Dalc'] <= 2 and row['Walc'] <= 2:
        if row['Dalc'] == 1 and row['Walc'] == 1:
            return 'Very Low'
        else:
            return 'Low'
    else:
        return 'Other'

df['classify_Alc'] = df.apply(classify_Alc, axis = 1)
# Out:
# C:\Users\Daylight\AppData\Local\Temp\ipykernel_24940\2864531220.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['classify_Alc'] = df.apply(classify_Alc, axis = 1)

# %%
### 성적 하락 및 상승 보기

temp = df['G1'] - df['G2']

for i in range(len(temp)):
    if temp.iloc[i] == 0:
        temp.iloc[i] = 'STAY'
    elif temp.iloc[i] < 0:
        temp.iloc[i] = 'UP'
    else:
        temp.iloc[i] = 'DOWN'

temp
# Out:
# 4        UP
# 5      STAY
# 6      DOWN
# 15     STAY
# 16     STAY
#        ...
# 562      UP
# 564    DOWN
# 565    STAY
# 570      UP
# 572    STAY
# Length: 177, dtype: object

# %%
df['diff_G'] = temp
# Out:
# C:\Users\Daylight\AppData\Local\Temp\ipykernel_24940\1114670070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diff_G'] = temp

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 562     MS   F   16       R     LE3       T     2     2     other  services
# 564     MS   M   16       R     GT3       T     3     2  services     other
# 565     MS   M   16       R     LE3       T     1     1   at_home     other
# 570     MS   M   16       R     GT3       T     2     2  services  services
# 572     MS   F   16       U     GT3       A     3     2  services   at_home
#
# ...

# %%
df_VeryLow = df[df['classify_Alc'] == 'Very Low']
df_Low = df[df['classify_Alc'] == 'Low']
df_Other = df[df['classify_Alc'] == 'Other']
